# %% [markdown]
# # Example usage
#
#
# ## CLI usage
#
# To use `allmetal3d` in a project:

# %%
import allmetal3d

print(allmetal3d.__version__)

# %% [markdown]
# ## Web app

# %% [markdown]
# ## Within python
